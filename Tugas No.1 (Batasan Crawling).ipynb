# %% [markdown]
# ## Mengimpor Fungsi Library Python dan API Address Twitter

# %%
import tweepy
from tweepy import OAuthHandler, Stream, StreamListener
import datetime

consumer_key="9gnPNqHJCTIRPWOeIVHoWvXxj"
consumer_secret="HIxLMOrSFFM44isSkR3J00Df2qBb2KbpaTMiLVoEjHZ1P3XqYv"
access_token="248112786-UPC1lD7fIKOdfxn0ZcwymNbZWyP68JOHSO5ce9oS"
access_token_secret="X2qIeYYZ7UclfGalhCh1bd4xGQuStxHENP2V3U74WyQSb"
auth = OAuthHandler (consumer_key, consumer_secret,)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %% [markdown]
# ## Berikut Tampilan Timeline Akun Twitter yang diinput API-nya

# %%
tweets = api.home_timeline()
for tweets in tweets:
    print (tweets.text)
# Out:
# Muhammadiyah lahirkan deretan Pahlawan Nasional
# ______________
# Follow Yuk
# Akun-akun kebaikan
# 👇👇👇👇
# IG @DoaHarian
# IG… https://t.co/x9H1nOBeVx
# RT @t_saddesttruth: Apa yang lebih serem dari ditinggal pas lagi sayang-sayangnya?
# Peluncuran perdananya akan dilakukan pada 12 November 2019. https://t.co/Xa5A3hY2C5
# Indonesian Art Festival diselenggarakan pada 9–18 November 2019 di Taman Sanken, Museum Nasional Indonesia, Jakarta. https://t.co/iR3lrFHQuf
# Sarwendah yang sederhana dan apa adanya membuat Ruben Onsu semakin jatuh cinta. #userstory https://t.co/C2YAXDhkGP
# Pemerintah mulai membuka pendaftaran CPNS 2019 tanggal 11 November 2019. https://t.co/JgNcxJEpI1
# Geopark Ciletuh Palabuhanratu dinilai mampu mendatangkan banyak wisatawan jika digarap secara serius. https://t.co/DNIcZH2Nob
# RT @theybring: 👸🏻: "We are waiting for Bigbang 5 members."
# ☀️: " I know. "
# 👸🏻: "Please tell SEUNGRI we miss him."
# ☀️: " I’ll do my best "…
# ...

# %% [markdown]
# ### Di bawah ini tampilan 200 tweets dari akun yang dicrawling datanya, sebagai contoh akun JKT48

# %%
user_tweets = api.user_timeline (screen_name='officialjkt48',count = 200, tweet_mode = "extended")
for tweet in user_tweets:
    print (tweet._json)
# Out:
# {'created_at': 'Sun Nov 10 07:49:22 +0000 2019', 'id': 1193435464708976640, 'id_str': '1193435464708976640', 'full_text': 'Selamat ulang tahun @R_KeisyaJKT48!\nKetangguhanmu menjadi inspirasi bagi banyak orang. Tetap semangat dan tersenyumlah selalu! #Ke15weetday https://t.co/IuRgzX9CEZ', 'truncated': False, 'display_text_range': [0, 139], 'entities': {'hashtags': [{'text': 'Ke15weetday', 'indices': [127, 139]}], 'symbols': [], 'user_mentions': [{'screen_name': 'R_KeisyaJKT48', 'name': 'Keisya Ramadhani', 'id': 1130446231824547841, 'id_str': '1130446231824547841', 'indices': [20, 34]}], 'urls': [], 'media': [{'id': 1193435420278677504, 'id_str': '1193435420278677504', 'indices': [140, 163], 'media_url': 'http://pbs.twimg.com/media/EI_vMRAUYAAMhxW.jpg', 'media_url_https': 'https://pbs.twimg.com/media/EI_vMRAUYAAMhxW.jpg', 'url': 'https://t.co/IuRgzX9CEZ', 'display_url': 'pic.twitter.com/IuRgzX9CEZ', 'expanded_url': 'https://twitter.com/officialJKT48/status/1193435464708976640/photo/1'
# ...

# %% [markdown]
# ### Berikut ini syntax untuk menampilkan data crawling berdasarkan limit waktu yang ditentukan, dalam hal ini dimulai dari tanggal 22 Oktober 2019 hingga 23 Oktober 2019

# %%
the_list = []
tweet_officialjkt48 = api.user_timeline(screen_name='officialjkt48',count=200,tweet_mode="extended")
start_date = datetime.datetime(2019, 10, 22, 00, 00, 00)
end_date = datetime.datetime(2019, 10, 23, 23, 59, 59)
for tweet in tweet_officialjkt48:
    the_list.append(tweet._json)

# %%
import pandas
myData = pandas.DataFrame(the_list)
myData
# Out:
#                          created_at                   id               id_str  \
# 0    Sun Nov 10 07:49:22 +0000 2019  1193435464708976640  1193435464708976640
# 1    Sat Nov 09 21:11:48 +0000 2019  1193275018047676416  1193275018047676416
# 2    Sat Nov 09 03:46:22 +0000 2019  1193011922972467200  1193011922972467200
# 3    Sat Nov 09 02:54:24 +0000 2019  1192998848093835266  1192998848093835266
# 4    Fri Nov 08 22:08:29 +0000 2019  1192926893692968960  1192926893692968960
# ..                              ...                  ...                  ...
# 195  Sat Oct 05 04:22:41 +0000 2019  1180337487526293504  1180337487526293504
# 196  Sat Oct 05 03:42:38 +0000 2019  1180327409104539648  1180327409104539648
# 197  Sat Oct 05 03:29:47 +0000 2019  1180324174167855107  1180324174167855107
# 198  Sat Oct 05 03:23:37 +0000 2019  1180322623177101314  1180322623177101314
# 199  Fri Oct 04 17:02:22 +0000 2019  1180166280403226624  1180166280403226624
#
# ...
